# %%
# !pip install \
 apache-airflow==1.10.12 \
 --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt"
# Out:
# Collecting apache-airflow==1.10.12
#   Using cached apache_airflow-1.10.12-py2.py3-none-any.whl (4.7 MB)
# Requirement already satisfied: json-merge-patch==0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 163)) (0.2)
# Collecting setproctitle==1.1.10
#   Using cached setproctitle-1.1.10.tar.gz (24 kB)
# Collecting lazy-object-proxy==1.5.1
#   Downloading lazy_object_proxy-1.5.1-cp38-cp38-win_amd64.whl (21 kB)
# Requirement already satisfied: email-validator==1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 101)) (1.1.1)
# Requirement already satisfied: Flask-Admin==1.5.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 3)) (1.5.4)
# Collecting iso8601==0.1.12
#   Downloading iso8601-0.1.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: python-slugify==4.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 256)) (4.0.1)
# Collecting argcomplete==1.12.0
#   Downloading argcomplete-1.12.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tabulate==0.8.7 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 302)) (0.8.7)
# Requirement already satisfied: Flask-WTF==0.14.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 12)) (0.14.3)
# Requirement already satisfied: croniter==0.3.34 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 85)) (0.3.34)
# Collecting funcsigs==1.0.2
#   Using cached funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: Jinja2==2.11.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 16)) (2.11.2)
# Requirement already satisfied: graphviz==0.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 139)) (0.14.1)
# Requirement already satisfied: Flask-Login==0.4.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 9)) (0.4.1)
# Requirement already satisfied: flask-swagger==0.2.14 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 109)) (0.2.14)
# Requirement already satisfied: Pygments==2.6.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 25)) (2.6.1)
# Requirement already satisfied: SQLAlchemy==1.3.18 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 28)) (1.3.18)
# Collecting psutil==5.7.2
#   Downloading psutil-5.7.2-cp38-cp38-win_amd64.whl (243 kB)
# Requirement already satisfied: attrs==19.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 47)) (19.3.0)
# Requirement already satisfied: python-nvd3==0.15.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 255)) (0.15.0)
# Collecting pandas==1.1.0
#   Downloading pandas-1.1.0-cp38-cp38-win_amd64.whl (9.6 MB)
# Requirement already satisfied: Flask-Caching==1.3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 7)) (1.3.3)
# Requirement already satisfied: python-daemon==2.2.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 249)) (2.2.4)
# Requirement already satisfied: Flask==1.1.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 13)) (1.1.2)
# Requirement already satisfied: Flask-AppBuilder==2.3.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 4)) (2.3.4)
# Processing c:\users\lenovo\appdata\local\pip\cache\wheels\93\7f\7d\78ec535a4340ef2696aad8b17fe8bb063d56301bd62881b069\dill-0.3.2-py3-none-any.whl
# Requirement already satisfied: thrift==0.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 307)) (0.13.0)
# Requirement already satisfied: pendulum==1.4.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 211)) (1.4.4)
# Requirement already satisfied: requests==2.24.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 271)) (2.24.0)
# Requirement already satisfied: configparser==3.5.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 83)) (3.5.3)
# Requirement already satisfied: Markdown==2.6.11 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 18)) (2.6.11)
# Requirement already satisfied: future==0.18.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 115)) (0.18.2)
# Requirement already satisfied: jsonschema==3.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 168)) (3.2.0)
# Requirement already satisfied: colorlog==4.0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 82)) (4.0.2)
# Requirement already satisfied: python-dateutil==2.8.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 250)) (2.8.1)
# Requirement already satisfied: tzlocal==1.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 314)) (1.5.1)
# Collecting alembic==1.4.2
#   Downloading alembic-1.4.2.tar.gz (1.1 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: gunicorn==20.0.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 143)) (20.0.4)
# Collecting cached-property==1.5.1
#   Downloading cached_property-1.5.1-py2.py3-none-any.whl (6.0 kB)
# Requirement already satisfied: cattrs==1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 71)) (1.0.0)
# Requirement already satisfied: SQLAlchemy-JSONField==0.9.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 26)) (0.9.0)
# Requirement already satisfied: tenacity==4.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 303)) (4.12.0)
# Requirement already satisfied: zope.deprecation==4.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 328)) (4.4.0)
# Requirement already satisfied: unicodecsv==0.14.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 315)) (0.14.1)
# Requirement already satisfied: Werkzeug==0.16.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 32)) (0.16.1)
# Requirement already satisfied: idna==2.10 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 150)) (2.10)
# Collecting dnspython==1.16.0
#   Downloading dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
# Requirement already satisfied: WTForms==2.3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 31)) (2.3.3)
# Requirement already satisfied: text-unidecode==1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 304)) (1.3)
# Requirement already satisfied: itsdangerous==1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 159)) (1.1.0)
# Requirement already satisfied: natsort==7.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 191)) (7.0.1)
# Requirement already satisfied: MarkupSafe==1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 19)) (1.1.1)
# Requirement already satisfied: PyYAML==5.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 24)) (5.3.1)
# Requirement already satisfied: pytz==2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 258)) (2020.1)
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp38-cp38-win_amd64.whl (13.0 MB)
# Requirement already satisfied: docutils==0.16 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 97)) (0.16)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from python-daemon==2.2.4->-c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 249)) (49.2.0.post20200714)
# Requirement already satisfied: lockfile==0.12.2 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 176)) (0.12.2)
# Collecting click==6.7
#   Downloading click-6.7-py2.py3-none-any.whl (71 kB)
# Requirement already satisfied: colorama==0.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 81)) (0.4.3)
# Requirement already satisfied: Flask-OpenID==1.2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 10)) (1.2.5)
# Requirement already satisfied: Flask-JWT-Extended==3.24.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 8)) (3.24.1)
# Requirement already satisfied: SQLAlchemy-Utils==0.36.8 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 27)) (0.36.8)
# Requirement already satisfied: marshmallow-sqlalchemy==0.23.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 178)) (0.23.1)
# Requirement already satisfied: apispec==1.3.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 40)) (1.3.3)
# Requirement already satisfied: marshmallow-enum==1.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 177)) (1.5.1)
# Requirement already satisfied: marshmallow==2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 179)) (2.21.0)
# Requirement already satisfied: PyJWT==1.7.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 21)) (1.7.1)
# Requirement already satisfied: Flask-SQLAlchemy==2.4.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 11)) (2.4.4)
# Requirement already satisfied: Flask-Babel==1.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 5)) (1.0.0)
# Requirement already satisfied: prison==0.1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 218)) (0.1.3)
# Requirement already satisfied: six==1.15.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 280)) (1.15.0)
# Requirement already satisfied: pytzdata==2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 259)) (2020.1)
# Collecting urllib3==1.25.10
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Requirement already satisfied: chardet==3.0.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 78)) (3.0.4)
# Requirement already satisfied: certifi==2020.6.20 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 73)) (2020.6.20)
# Requirement already satisfied: pyrsistent==0.16.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 240)) (0.16.0)
# Requirement already satisfied: Mako==1.1.3 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 17)) (1.1.3)
# Requirement already satisfied: python-editor==1.0.4 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 251)) (1.0.4)
# Requirement already satisfied: python3-openid==3.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 257)) (3.2.0)
# Requirement already satisfied: Babel==2.8.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 2)) (2.8.0)
# Requirement already satisfied: defusedxml==0.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from -c https://raw.githubusercontent.com/apache/airflow/constraints-1.10.12/constraints-3.7.txt (line 90)) (0.6.0)
# Building wheels for collected packages: alembic, setproctitle
#   Building wheel for alembic (PEP 517): started
#   Building wheel for alembic (PEP 517): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.2-py2.py3-none-any.whl size=159547 sha256=0fb9df7ba2a82afdc90b17bbc2329c5cf4300dfd89bff77228c405a06ed40551
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\70\08\70\cea787a7e95817b831469fa42af076046e55a05f7c94657463
#   Building wheel for setproctitle (setup.py): started
#   Building wheel for setproctitle (setup.py): finished with status 'error'
#   Running setup.py clean for setproctitle
# Successfully built alembic
# Failed to build setproctitle
# Installing collected packages: alembic, argcomplete, cached-property, click, dill, dnspython, funcsigs, iso8601, lazy-object-proxy, numpy, pandas, psutil, setproctitle, urllib3, apache-airflow
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.4.3
#     Uninstalling alembic-1.4.3:
#       Successfully uninstalled alembic-1.4.3
#   Attempting uninstall: argcomplete
#     Found existing installation: argcomplete 1.12.1
#     Uninstalling argcomplete-1.12.1:
#       Successfully uninstalled argcomplete-1.12.1
#   Attempting uninstall: cached-property
#     Found existing installation: cached-property 1.5.2
#     Uninstalling cached-property-1.5.2:
#       Successfully uninstalled cached-property-1.5.2
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.1.1
#     Uninstalling dill-0.3.1.1:
#       Successfully uninstalled dill-0.3.1.1
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 2.0.0
#     Uninstalling dnspython-2.0.0:
#       Successfully uninstalled dnspython-2.0.0
#   Attempting uninstall: iso8601
#     Found existing installation: iso8601 0.1.13
#     Uninstalling iso8601-0.1.13:
#       Successfully uninstalled iso8601-0.1.13
#   Attempting uninstall: lazy-object-proxy
#     Found existing installation: lazy-object-proxy 1.4.3
#     Uninstalling lazy-object-proxy-1.4.3:
#       Successfully uninstalled lazy-object-proxy-1.4.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.7.0
#     Uninstalling psutil-5.7.0:
#       Successfully uninstalled psutil-5.7.0
#     Running setup.py install for setproctitle: started
#     Running setup.py install for setproctitle: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\lenovo\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"'; __file__='"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\lenovo\AppData\Local\Temp\pip-wheel-ek5jbdbk'
#        cwd: C:\Users\lenovo\AppData\Local\Temp\pip-install-ectrn14_\setproctitle\
#   Complete output (5 lines):
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'setproctitle' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#   ----------------------------------------
#   ERROR: Failed building wheel for setproctitle
# ERROR: spyder 4.1.4 requires pyqt5<5.13; python_version >= "3", which is not installed.
# ERROR: spyder 4.1.4 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: tfx 0.24.0 has requirement click<8,>=7, but you'll have click 6.7 which is incompatible.
# ERROR: tensorflow 2.3.1 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.1 which is incompatible.
# ERROR: astroid 2.4.2 has requirement lazy-object-proxy==1.4.*, but you'll have lazy-object-proxy 1.5.1 which is incompatible.
# ERROR: apache-beam 2.24.0 has requirement dill<0.3.2,>=0.3.1.1, but you'll have dill 0.3.2 which is incompatible.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\lenovo\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"'; __file__='"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\lenovo\AppData\Local\Temp\pip-record-qv1uvjft\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\lenovo\anaconda3\Include\setproctitle'
#          cwd: C:\Users\lenovo\AppData\Local\Temp\pip-install-ectrn14_\setproctitle\
#     Complete output (5 lines):
#     running install
#     running build
#     running build_ext
#     building 'setproctitle' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\lenovo\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"'; __file__='"'"'C:\\Users\\lenovo\\AppData\\Local\\Temp\\pip-install-ectrn14_\\setproctitle\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\lenovo\AppData\Local\Temp\pip-record-qv1uvjft\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\lenovo\anaconda3\Include\setproctitle' Check the logs for full command output.
